# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import pybullet as p
import pybullet_data
import time
import math
import numpy as np
import json
import matplotlib.pyplot as plt

from scripts.buffer import ReplayBuffer
from scripts.SAC import AgentSAC
from scripts.lidar import lidar_sim
from scripts.utils import diff_drive_control, get_state, compute_reward_done, get_spawn, get_goal, setupEnvironment, dict_to_tensors
from scripts.slam import SLAM

# %%
# DEFINE VARIABLES AND HYPERPARAMETERS
PI = math.pi
NUM_EPISODES = 2000
ACTION_DURATION = 0.5
STEP_ACTION_DUARTION = int(ACTION_DURATION * 240.0)
MAX_EPISODE_TIME = 60
MAX_STEPS_PER_EPISODE = int(MAX_EPISODE_TIME / ACTION_DURATION)
NEW_GOAL_EVERY = 1
SAVE_EVERY = 50
DELTA_T = 0.01

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
# Load Environment
physicsClient = p.connect(p.DIRECT)
p.setGravity(0, 0, -9.8)
# p.setTimeStep(DELTA_T)
p.setAdditionalSearchPath(pybullet_data.getDataPath())
setupEnvironment()

p.loadURDF('plane.urdf')

init_pos = [0, 0, 0]
init_orientation = p.getQuaternionFromEuler([0, 0, 0])
robotId = p.loadURDF('diff_drive_robot/diff_drive_robot.urdf', basePosition=init_pos, baseOrientation=init_orientation)
p.changeDynamics(robotId, linkIndex=-1, lateralFriction=0.0, spinningFriction=0.0, rollingFriction=0.0)
p.changeDynamics(robotId, 0, lateralFriction=5.0)
p.changeDynamics(robotId, 1, lateralFriction=5.0)
num_joints = p.getNumJoints(robotId) - 1

# %%
batch_size = 64
agent = AgentSAC(state_dim=495, action_dim=2).to(device)
buffer = ReplayBuffer(capacity=10000, batch_size=batch_size)
slam_node = SLAM(robotId)

reward_tracking = []
dist_goal_tracking = []
step_tracking = []

# %%
agent.train()
for episode in range(NUM_EPISODES):
    
    # set spawn and goal
    if episode % NEW_GOAL_EVERY == 0:
        # set spawn
        spawn = get_spawn()
        new_position = [spawn[0], spawn[1], 0.05]
        new_orientation = p.getQuaternionFromEuler([0, 0, spawn[2]])
        
        # set goal
        goal = get_goal(new_position)
    
    # reset robot pose in environment    
    p.resetBasePositionAndOrientation(robotId, posObj=new_position, ornObj=new_orientation)

    # collect initial state
    slam_node.set_robot_pose(spawn[0], spawn[1], spawn[2])
    state = get_state(robotId, goal, slam_node)
    total_reward = 0
    done = False
    print(f'Started episode, with spawn: [{spawn[0]},{spawn[1]}],  {episode}, with goal: {goal}')
    for step in range(MAX_STEPS_PER_EPISODE):
        
        # update map
        slam_node.update_map(robotId)
        
        # choose and perform action
        s_ = dict_to_tensors(state)
        action, _ = agent.actor.sample(s_['map'], s_['lidar'], s_['robot'])
        action = action.squeeze().detach().cpu().numpy()
        action_drive = diff_drive_control(linear_vel=action[0], angular_vel=action[1])
        p.setJointMotorControlArray(robotId, range(num_joints), controlMode=p.VELOCITY_CONTROL, targetVelocities=action_drive, forces=[100, 100])
        start_time = time.time()
        for _ in range(STEP_ACTION_DUARTION):
            p.stepSimulation()
            linear_vel, angular_vel = p.getBaseVelocity(robotId)
            slam_node.motion_model(linear_vel, angular_vel)
            # time.sleep(DELTA_T)

        # collect new state
        next_state = get_state(robotId, goal, slam_node)

        # get reward and done
        reward, done = compute_reward_done(state, action, next_state)
        total_reward += reward

        # store transition in buffer
        buffer.push(state, action, next_state, reward, done)

        # update model
        if len(buffer) >= batch_size:
            # sample from batch
            states, actions, next_states, rewards, dones = buffer.sample()
            # update critic 
            agent.update_critic(states, actions, next_states, rewards, dones)
    
            # update actor
            agent.update_actor(states)

        # break if done
        if done:
            break

        # update state
        state = next_state
    
    robot_pos, _ = p.getBasePositionAndOrientation(robotId)
    dist_to_goal = np.sqrt((robot_pos[0] - goal[0])**2  + (robot_pos[1] - goal[1])**2)

    # Results log
    print(f'Finished episode {episode} with total reward {total_reward}, average reward {total_reward / (step+1)}, distance to goal: {dist_to_goal}, in {step+1} steps')
    reward_tracking.append(total_reward)
    dist_goal_tracking.append(dist_to_goal)
    step_tracking.append(step)

    # Save model every few steps
    if episode % SAVE_EVERY == 0 or episode == NUM_EPISODES-1:
        torch.save(agent.state_dict(), f'saves/model_state_{episode}.pth')

# Save training data
with open('training_log/training_log_2.json', 'w') as file:
    json.dump({'Reward': reward_tracking, 'Distance': dist_goal_tracking, 'Steps': step_tracking}, file)
# Out:
# Started episode, with spawn: [3.0094905145237885,-10.724467817798619],  0, with goal: [8.494643302045384, -12.5]
# Finished episode 0 with total reward -203.88717651278108, average reward -18.53519786479828, distance to goal: 6.036961710377423, in 11 steps
# Started episode, with spawn: [2.9635789361151694,-1.4785053385850944],  1, with goal: [7.306761470526781, -3.0126816975780595]
# Finished episode 1 with total reward -216.43289039142613, average reward -3.13670855639748, distance to goal: 4.893303707777274, in 69 steps
# Started episode, with spawn: [2.0455065644205312,1.1141735575356932],  2, with goal: [2.1001160861892187, 1.1501602247873426]
# Finished episode 2 with total reward -211.19311096329753, average reward -3.5795442536152122, distance to goal: 0.5691237541753736, in 59 steps
# Started episode, with spawn: [6.926048524468889,5.738159936109472],  3, with goal: [5.770044467465408, 5.54235992875241]
# Finished episode 3 with total reward 89.11924011093255, average reward 1.1726215804070073, distance to goal: 0.11909524578727802, in 76 steps
# Started episode, with spawn: [1.498980408032299,-3.468512641768422],  4, with goal: [1.1653416873635756, -4.023132411852903]
# Finished episode 4 with total reward -210.91512713566118, average reward -6.026146489590319, distance to goal: 1.4805725958158582, in 35 steps
# Started episode, with spawn: [-10.026156508591544,-8.870937887455595],  5, with goal: [-7.566849636088534, -12.5]
# Finished episode 5 with total reward -23.784372658748882, average reward -0.198203105489574, distance to goal: 4.378994209578064, in 120 steps
# Started episode, with spawn: [-11.434084911866817,-0.7219709435348527],  6, with goal: [-9.791107195816213, 3.826486233782246]
# Finished episode 6 with total reward -226.78785764415446, average reward -3.8438619939687197, distance to goal: 7.802123902241605, in 59 steps
# Started episode, with spawn: [-6.085464956368909,10.41202567976271],  7, with goal: [-8.051616602091013, 6.480159226107551]
# Finished episode 7 with total reward -211.03315671224988, average reward -4.058329936774036, distance to goal: 4.790318760312935, in 52 steps
# Started episode, with spawn: [-10.871474383992844,-5.342597945591122],  8, with goal: [-2.6787911494959573, -4.718715149570557]
# Finished episode 8 with total reward -200.77214930592987, average reward -3.6504027146532705, distance to goal: 6.519411484868544, in 55 steps
# Started episode, with spawn: [3.0858575279081837,-0.9873675433214704],  9, with goal: [-4.756217388916744, 5.173966855119327]
# Finished episode 9 with total reward -205.86327097020686, average reward -25.732908871275857, distance to goal: 10.589943111540542, in 8 steps
# Started episode, with spawn: [7.179327087875496,0.008527226099309004],  10, with goal: [1.0644229129324012, -0.29641527954011115]
# Finished episode 10 with total reward -221.6534251638068, average reward -4.523539289057282, distance to goal: 7.989354047755556, in 49 steps
# Started episode, with spawn: [-4.863823775559946,-8.167941323875691],  11, with goal: [-5.423446403971493, -9.033436802655501]
# Finished episode 11 with total reward -205.81107347138158, average reward -25.726384183922697, distance to goal: 1.8851967972064774, in 8 steps
# Started episode, with spawn: [-11.193805816589462,9.830526926326648],  12, with goal: [-10.199473253571613, 5.687116886389112]
# Finished episode 12 with total reward -223.3964246399172, average reward -6.037741206484249, distance to goal: 7.3201666115641535, in 37 steps
# Started episode, with spawn: [1.6113046774953226,-6.046326424161038],  13, with goal: [10.367268467064747, -10.52456558528722]
# Finished episode 13 with total reward -205.32540363931412, average reward -2.360062110796714, distance to goal: 8.038277680702503, in 87 steps
# Started episode, with spawn: [-10.994169016581045,-4.073530952958536],  14, with goal: [-12.5, 2.952780248604987]
# Finished episode 14 with total reward -209.60017880237197, average reward -11.031588358019578, distance to goal: 8.363149752602736, in 19 steps
# Started episode, with spawn: [3.7125083928468943,-9.043793085003035],  15, with goal: [6.2393907327919695, -12.5]
# Finished episode 15 with total reward -29.132563975796778, average reward -0.24277136646497316, distance to goal: 6.168791635080711, in 120 steps
# Started episode, with spawn: [5.806452820368001,5.766869519882924],  16, with goal: [12.5, 6.132499883534384]
# Finished episode 16 with total reward -16.558307429892785, average reward -0.13798589524910654, distance to goal: 6.243180825546044, in 120 steps
# Started episode, with spawn: [7.488960261404422,5.250932038451847],  17, with goal: [7.053141730356063, 5.077829819317089]
# Finished episode 17 with total reward -213.79810040369398, average reward -4.548895753270084, distance to goal: 1.3366624762530013, in 47 steps
# Started episode, with spawn: [-10.514296395845196,2.6192866168500757],  18, with goal: [-10.416236387051153, 9.557427014471413]
# Finished episode 18 with total reward -216.71203788937387, average reward -2.1456637414789492, distance to goal: 6.636659548927567, in 101 steps
# Started episode, with spawn: [5.989120586180739,-2.845872433965413],  19, with goal: [6.781905009410712, -2.622974764058523]
# Finished episode 19 with total reward -242.8183350968527, average reward -2.6109498397511044, distance to goal: 5.910718147000471, in 93 steps
# Started episode, with spawn: [-7.411644015369349,4.3542803679741215],  20, with goal: [-1.4291263335512125, 2.4597391745761428]
# Finished episode 20 with total reward -15.694035791651874, average reward -0.13078363159709896, distance to goal: 5.767548025164801, in 120 steps
# Started episode, with spawn: [-4.361154415868746,-11.314838461415839],  21, with goal: [-4.491185528118337, -12.07575449814517]
# Finished episode 21 with total reward -249.2780786059639, average reward -3.0775071432835053, distance to goal: 7.253544205268898, in 81 steps
# Started episode, with spawn: [-6.835990861509682,3.836014007284037],  22, with goal: [-6.478453213390793, 3.5792210662367707]
# Finished episode 22 with total reward -33.195273754706186, average reward -0.2766272812892182, distance to goal: 3.072441818203785, in 120 steps
# Started episode, with spawn: [-10.21780160977653,3.154368963516818],  23, with goal: [-12.5, 1.3552713869038713]
# Finished episode 23 with total reward -86.53979779718127, average reward -0.7211649816431772, distance to goal: 15.061356706921798, in 120 steps
# Started episode, with spawn: [7.673511630467772,-7.624386894880475],  24, with goal: [8.734016391622516, -8.426533919579203]
# Finished episode 24 with total reward -86.48683584776151, average reward -0.7207236320646793, distance to goal: 14.300925295640482, in 120 steps
# Started episode, with spawn: [-9.68097780009618,3.170068447954346],  25, with goal: [-10.513592122879356, 0.9918156660754831]
# Finished episode 25 with total reward -71.19112037284434, average reward -0.5932593364403694, distance to goal: 11.509614620553123, in 120 steps
# Started episode, with spawn: [-2.7509471731011494,-0.8659886992615853],  26, with goal: [-10.93770829089926, -0.40182673901761345]
# Finished episode 26 with total reward -44.6020554282526, average reward -0.3716837952354383, distance to goal: 12.55044934920446, in 120 steps
# Started episode, with spawn: [5.02727235762552,2.666964590518747],  27, with goal: [0.8836422910446062, 0.17460544910344655]
# Finished episode 27 with total reward -55.959720043748966, average reward -0.4663310003645747, distance to goal: 11.527546307273662, in 120 steps
# Started episode, with spawn: [3.8428104429534926,-0.6921938308671081],  28, with goal: [-4.3055733368048905, 1.9447662267450725]
# Finished episode 28 with total reward -51.87564425368238, average reward -0.43229703544735315, distance to goal: 13.225160963788973, in 120 steps
# Started episode, with spawn: [-8.434301562056998,9.21757939334491],  29, with goal: [-11.852212514542687, 1.948720288871745]
# Finished episode 29 with total reward -18.193519808577175, average reward -0.15161266507147647, distance to goal: 7.020123228545306, in 120 steps
# Started episode, with spawn: [-11.298963022446744,0.4988965485776671],  30, with goal: [-11.985577487217984, 0.48064061030694233]
# Finished episode 30 with total reward -48.28812095037862, average reward -0.4024010079198218, distance to goal: 4.714162225529399, in 120 steps
# Started episode, with spawn: [-6.837180538845553,0.5160601038585142],  31, with goal: [-5.766900317809891, -1.6431430049266242]
# Finished episode 31 with total reward -227.35779368739952, average reward -3.1577471345472157, distance to goal: 5.241655444142179, in 72 steps
# Started episode, with spawn: [5.313911460988656,-0.16001183602750046],  32, with goal: [6.977269720570419, 0.6763372648008987]
# Finished episode 32 with total reward 89.66252059709738, average reward 0.9149236795622182, distance to goal: 0.09538204661751268, in 98 steps
# Started episode, with spawn: [0.11156484874514128,-7.922444581964266],  33, with goal: [3.731612351406778, -5.203215125708654]
# Finished episode 33 with total reward -20.43371515772915, average reward -0.17028095964774292, distance to goal: 3.3857793320869214, in 120 steps
# Started episode, with spawn: [7.571174576956931,5.98696076252693],  34, with goal: [8.26114405590171, 9.530200146681008]
# Finished episode 34 with total reward -213.14908939841223, average reward -3.6749842999726248, distance to goal: 3.875039477226811, in 58 steps
# Started episode, with spawn: [-1.8485871237599323,3.532756500881016],  35, with goal: [-0.5682104494837399, 3.2983063986918255]
# Finished episode 35 with total reward -32.94486505775108, average reward -0.27454054214792567, distance to goal: 2.6092356092883806, in 120 steps
# Started episode, with spawn: [7.560093091306776,10.947079511376295],  36, with goal: [-1.1447893497357313, 12.5]
# Finished episode 36 with total reward -18.84527493812034, average reward -0.1570439578176695, distance to goal: 6.293431969662847, in 120 steps
# Started episode, with spawn: [-3.0725148214884985,0.32426021870596244],  37, with goal: [-2.0812946641863648, -0.8360326471937654]
# Finished episode 37 with total reward -203.46969373486485, average reward -15.651514902681912, distance to goal: 1.6649435136905244, in 13 steps
# Started episode, with spawn: [6.375676334297484,-6.902249101508466],  38, with goal: [8.640946293485563, -6.348800738146314]
# Finished episode 38 with total reward -52.81093701207012, average reward -0.440091141767251, distance to goal: 7.293184220331771, in 120 steps
# Started episode, with spawn: [-5.718446248600313,-3.046116095145205],  39, with goal: [-5.611988413978119, -3.068205390467798]
# Finished episode 39 with total reward 97.11490822146511, average reward 8.828628020133193, distance to goal: 0.20381131403403213, in 11 steps
# Started episode, with spawn: [-10.219454613039394,-0.45676475704255104],  40, with goal: [-4.062032546926284, -1.5482032954607472]
# Finished episode 40 with total reward -14.123479264575412, average reward -0.11769566053812844, distance to goal: 3.9660255892548415, in 120 steps
# Started episode, with spawn: [0.7975884497896484,-4.984728719957503],  41, with goal: [2.289980272793116, -6.615607916898159]
# Finished episode 41 with total reward -49.89762336572125, average reward -0.4158135280476771, distance to goal: 6.883633640949764, in 120 steps
# Started episode, with spawn: [-9.335873280732978,-5.241410342051968],  42, with goal: [-10.69082630484349, -4.213735052427463]
# Finished episode 42 with total reward -58.924118338431974, average reward -0.4910343194869331, distance to goal: 7.601809442223056, in 120 steps
# Started episode, with spawn: [-9.857040075627118,4.2288914949667085],  43, with goal: [-10.065005372968741, 5.387004610680151]
# Finished episode 43 with total reward -82.47511520232155, average reward -0.6872926266860129, distance to goal: 11.914235333397787, in 120 steps
# Started episode, with spawn: [-5.7954526089476905,-8.720231221367154],  44, with goal: [-9.370285737473537, -10.069205414629039]
# Finished episode 44 with total reward -23.48935454881271, average reward -0.19574462124010591, distance to goal: 2.0124400798671984, in 120 steps
# Started episode, with spawn: [-9.636484243542293,9.229802305569404],  45, with goal: [-10.629562337975273, 12.5]
# Finished episode 45 with total reward -242.14264138224493, average reward -4.035710689704082, distance to goal: 9.013002806155155, in 60 steps
# Started episode, with spawn: [1.826627153139734,-1.3471166511961457],  46, with goal: [-0.7194985289336047, 2.711316809373483]
# Finished episode 46 with total reward -33.79987555898089, average reward -0.28166562965817404, distance to goal: 5.382420466030355, in 120 steps
# Started episode, with spawn: [3.4169688377122114,10.173437388594323],  47, with goal: [1.6047647101158375, 12.5]
# Finished episode 47 with total reward -70.09128047041519, average reward -0.5840940039201266, distance to goal: 11.742861427758271, in 120 steps
# Started episode, with spawn: [-2.69677437546971,4.847668898634566],  48, with goal: [-4.032652548746363, 5.159019874864572]
# Finished episode 48 with total reward -44.88240242077601, average reward -0.3740200201731334, distance to goal: 3.3001191334287046, in 120 steps
# Started episode, with spawn: [-3.446846541644682,-8.389218332444582],  49, with goal: [-2.7061075195462765, -10.015540556110881]
# Finished episode 49 with total reward -218.91549261293264, average reward -3.127364180184752, distance to goal: 1.7759465062350854, in 70 steps
# Started episode, with spawn: [-5.4987450233845205,-3.488976320547689],  50, with goal: [-1.120764281857177, -11.402710594304564]
# Finished episode 50 with total reward -46.91877824266624, average reward -0.3909898186888853, distance to goal: 12.603059669598487, in 120 steps
# Started episode, with spawn: [-6.4185893786801556,5.830752584940878],  51, with goal: [-12.25880946261221, -0.6617283213406369]
# Finished episode 51 with total reward -208.08965101876117, average reward -3.1058156868471816, distance to goal: 6.746717955700618, in 67 steps
# Started episode, with spawn: [7.831379033292091,-3.2080590601699868],  52, with goal: [5.439885891680083, 1.5215190499614968]
# Finished episode 52 with total reward -19.43652725133388, average reward -0.16197106042778234, distance to goal: 2.7789168558064046, in 120 steps
# Started episode, with spawn: [-6.4499912589814965,2.110140602940996],  53, with goal: [-3.962936177297963, 7.799078581769148]
# Finished episode 53 with total reward -8.314088554712562, average reward -0.06928407128927135, distance to goal: 2.2510544749810695, in 120 steps
# Started episode, with spawn: [-2.505644509905366,-5.9885569091154425],  54, with goal: [-3.0124121030924784, -10.207339934609761]
# Finished episode 54 with total reward -22.339890208519634, average reward -0.18616575173766362, distance to goal: 2.7662520939590554, in 120 steps
# Started episode, with spawn: [10.503108504828223,-10.534378838620823],  55, with goal: [6.933609857450945, -12.5]
# Finished episode 55 with total reward -216.39004096213864, average reward -16.645387766318358, distance to goal: 6.128835480954423, in 13 steps
# Started episode, with spawn: [2.049336077955372,-1.0863258837310443],  56, with goal: [-2.7716803750679766, 0.6758591858342564]
# Finished episode 56 with total reward -225.31140775810658, average reward -4.8980740816979695, distance to goal: 7.1943213211471715, in 46 steps
# Started episode, with spawn: [10.09127720159647,-6.037718998785669],  57, with goal: [10.568340667066703, -8.042761509473891]
# Finished episode 57 with total reward -261.7898360808917, average reward -4.759815201470758, distance to goal: 11.544853640791326, in 55 steps
# Started episode, with spawn: [3.6921972605166538,9.158420207968163],  58, with goal: [11.526523833666317, 3.0163070937600684]
# Finished episode 58 with total reward -5.771155743614539, average reward -0.04809296453012116, distance to goal: 5.590791023122109, in 120 steps
# Started episode, with spawn: [-7.195110069828844,6.846268647453499],  59, with goal: [-8.609956419051306, 5.720890350943473]
# Finished episode 59 with total reward -28.91061449135786, average reward -0.24092178742798218, distance to goal: 0.5963981616271407, in 120 steps
# Started episode, with spawn: [3.055410346511332,-7.380406823662712],  60, with goal: [7.878348860740404, -7.148567609265719]
# Finished episode 60 with total reward -199.20570593695632, average reward -9.054804815316196, distance to goal: 3.4469002591104654, in 22 steps
# Started episode, with spawn: [5.331007113709557,-3.225697269552322],  61, with goal: [0.6480498538738004, -8.528953637001663]
# Finished episode 61 with total reward -21.34453920050481, average reward -0.17787116000420675, distance to goal: 4.532962144694088, in 120 steps
# Started episode, with spawn: [-2.483196161587646,7.7360363553527165],  62, with goal: [-3.4838249803522015, 8.422263747706804]
# Finished episode 62 with total reward 102.57803312370197, average reward 9.32527573851836, distance to goal: 0.1505026295308217, in 11 steps
# Started episode, with spawn: [-8.534429092221636,-0.09828269600793504],  63, with goal: [-7.632613409636586, -6.461922048918592]
# Finished episode 63 with total reward -42.6811478666278, average reward -0.35567623222189837, distance to goal: 8.803040261919948, in 120 steps
# Started episode, with spawn: [6.867672907857102,4.873726015936384],  64, with goal: [11.526771756320635, -0.6596611620336637]
# Finished episode 64 with total reward -4.565893788806438, average reward -0.03804911490672032, distance to goal: 2.6584507047072177, in 120 steps
# Started episode, with spawn: [-8.222087570945257,10.96246266324222],  65, with goal: [-7.165883608924453, 9.850357637261608]
# Finished episode 65 with total reward -34.01079004033685, average reward -0.2834232503361404, distance to goal: 2.1074277106524772, in 120 steps
# Started episode, with spawn: [0.8352762599805565,-2.573087784231589],  66, with goal: [3.412560304932115, -5.512114404784992]
# Finished episode 66 with total reward -83.09580563896014, average reward -0.6924650469913345, distance to goal: 14.66685016085204, in 120 steps
# Started episode, with spawn: [-9.768523495033358,8.179272246067992],  67, with goal: [-12.5, 9.754615779421194]
# Finished episode 67 with total reward -242.35564651949093, average reward -3.275076304317445, distance to goal: 7.7788536839630105, in 74 steps
# Started episode, with spawn: [5.242281307692036,-7.5824324526186455],  68, with goal: [4.0681064055027365, -6.8026111564117215]
# Finished episode 68 with total reward -64.13643413996023, average reward -0.5344702844996686, distance to goal: 7.3591624533434725, in 120 steps
# Started episode, with spawn: [-7.079530408840969,7.557668344525496],  69, with goal: [-4.836388053213366, 11.686622641417419]
# Finished episode 69 with total reward -223.2640778960526, average reward -4.293539959539474, distance to goal: 6.851872529143958, in 52 steps
# Started episode, with spawn: [0.03592067622718176,7.038383090456044],  70, with goal: [-8.342362680259763, 4.980577579119956]
# Finished episode 70 with total reward -203.62696363811907, average reward -4.735510782281839, distance to goal: 6.922888295583551, in 43 steps
# Started episode, with spawn: [-4.329242662161925,-7.775931900414793],  71, with goal: [-11.379865989959956, -4.998708786713138]
# Finished episode 71 with total reward -45.61208372522042, average reward -0.3801006977101702, distance to goal: 9.651674055734532, in 120 steps
# Started episode, with spawn: [8.061608092587335,1.3987232261423177],  72, with goal: [6.274274437445303, 1.2840783022563547]
# Finished episode 72 with total reward -63.956138284480126, average reward -0.5329678190373344, distance to goal: 7.942420061780178, in 120 steps
# Started episode, with spawn: [-8.28010075728658,-2.427908655554777],  73, with goal: [-9.393438081223634, -5.851985875121961]
# Finished episode 73 with total reward -40.775927514185945, average reward -0.33979939595154957, distance to goal: 5.384303034425289, in 120 steps
# Started episode, with spawn: [-9.298303558742258,-2.637507359162754],  74, with goal: [-11.709992081660792, 5.89677730941888]
# Finished episode 74 with total reward -13.33728924393894, average reward -0.1111440770328245, distance to goal: 5.16597088780533, in 120 steps
# Started episode, with spawn: [9.260614963691904,-3.825852399256031],  75, with goal: [2.398517409667506, 0.07839563772179226]
# Finished episode 75 with total reward -213.81881727840567, average reward -3.1913256310209803, distance to goal: 6.755770042483133, in 67 steps
# Started episode, with spawn: [-1.9972216892965786,7.320744761044988],  76, with goal: [-3.2319174625378184, 1.7065879841231881]
# Finished episode 76 with total reward -29.414609095134036, average reward -0.24512174245945031, distance to goal: 5.419969264203093, in 120 steps
# Started episode, with spawn: [-10.335025798309223,-10.307741177174123],  77, with goal: [-10.772000027945294, -8.873540581944193]
# Finished episode 77 with total reward -35.112572352232036, average reward -0.29260476960193366, distance to goal: 2.0721410344635065, in 120 steps
# Started episode, with spawn: [8.423594517894848,-7.398200195474569],  78, with goal: [6.00282492583046, -4.731240681515358]
# Finished episode 78 with total reward -35.13023331289854, average reward -0.2927519442741545, distance to goal: 3.8748736840780107, in 120 steps
# Started episode, with spawn: [1.5974432913691938,-1.47788983262447],  79, with goal: [-1.6069915759465, -0.5699567763264717]
# Finished episode 79 with total reward -39.77121948417603, average reward -0.33142682903480025, distance to goal: 4.509108577246806, in 120 steps
# Started episode, with spawn: [5.660621436107,6.706189996867934],  80, with goal: [4.985735631879402, 5.3003874217031255]
# Finished episode 80 with total reward -42.02600675786569, average reward -0.35021672298221407, distance to goal: 4.072987240458297, in 120 steps
# Started episode, with spawn: [5.552352848346366,-8.605887727165278],  81, with goal: [8.444670376486684, -11.254327676710854]
# Finished episode 81 with total reward -40.75836256471994, average reward -0.3396530213726662, distance to goal: 6.1192803468956445, in 120 steps
# Started episode, with spawn: [5.102860138810694,-3.2184363006060295],  82, with goal: [-0.035644210675697785, 3.3722189355993475]
# Finished episode 82 with total reward -232.25226232674916, average reward -2.609575981199429, distance to goal: 10.031403281947448, in 89 steps
# Started episode, with spawn: [-0.5358602521255094,10.5499786298546],  83, with goal: [-1.725713604274015, 5.335690601570027]
# Finished episode 83 with total reward -205.51994611701832, average reward -3.6699990378038985, distance to goal: 3.581282436788525, in 56 steps
# Started episode, with spawn: [0.3742254593917167,-2.680788595707046],  84, with goal: [3.157307058999996, 1.029339472143465]
# Finished episode 84 with total reward -214.5399274516287, average reward -4.564679307481462, distance to goal: 5.336568644997964, in 47 steps
# Started episode, with spawn: [-1.3558738400982033,-11.208679378691546],  85, with goal: [-1.6234472764823629, -12.177600570748343]
# Finished episode 85 with total reward -43.738481557227075, average reward -0.3644873463102256, distance to goal: 3.544431383283799, in 120 steps
# Started episode, with spawn: [11.37365255084072,2.5054085139315383],  86, with goal: [9.378353481653441, 0.022313704631127695]
# Finished episode 86 with total reward -33.658382811783234, average reward -0.28048652343152697, distance to goal: 3.3666810378784624, in 120 steps
# Started episode, with spawn: [-11.171833633848614,-5.898270100199186],  87, with goal: [-12.5, -1.9508331664433598]
# Finished episode 87 with total reward -23.56705676432697, average reward -0.19639213970272476, distance to goal: 2.347094219578798, in 120 steps
# Started episode, with spawn: [6.00205990738095,5.752938805106048],  88, with goal: [9.342406745366361, 0.8076225908662966]
# Finished episode 88 with total reward -17.34087558580285, average reward -0.14450729654835706, distance to goal: 3.8763269005827365, in 120 steps
# Started episode, with spawn: [7.854650591381624,-6.001282688540567],  89, with goal: [12.041317635378624, -10.973197916992172]
# Finished episode 89 with total reward -44.76131785455963, average reward -0.3730109821213302, distance to goal: 9.798434882761823, in 120 steps
# Started episode, with spawn: [-11.495978052815966,7.68541304112469],  90, with goal: [-5.808144377150112, 8.824384141224948]
# Finished episode 90 with total reward -22.720366392539987, average reward -0.1893363866044999, distance to goal: 4.928866821159711, in 120 steps
# Started episode, with spawn: [-6.319963149170488,10.704243262007903],  91, with goal: [-5.0687067561956, 12.5]
# Finished episode 91 with total reward -36.00619646119152, average reward -0.300051637176596, distance to goal: 3.5715339511867787, in 120 steps
# Started episode, with spawn: [8.029234024667382,1.2405959476124444],  92, with goal: [12.5, -4.1274439619764784]
# Finished episode 92 with total reward -209.06748123277276, average reward -2.459617426267915, distance to goal: 4.714638406786295, in 85 steps
# Started episode, with spawn: [3.5222412097122167,-0.9640052241976722],  93, with goal: [1.8137222201614314, -0.5709806273590303]
# Finished episode 93 with total reward -54.09526780846548, average reward -0.450793898403879, distance to goal: 6.0667189876386125, in 120 steps
# Started episode, with spawn: [4.78269791229237,10.939235951694762],  94, with goal: [6.375887882828126, 4.938589126383321]
# Finished episode 94 with total reward -193.70301705076747, average reward -14.900232080828268, distance to goal: 4.3678982778319, in 13 steps
# Started episode, with spawn: [8.297779536874728,9.71827594821325],  95, with goal: [2.8348655033470225, 11.465747175650266]
# Finished episode 95 with total reward -28.1671588245141, average reward -0.2347263235376175, distance to goal: 4.88513136814726, in 120 steps
# Started episode, with spawn: [4.920840596939872,-8.687111983368517],  96, with goal: [4.2433305597151705, -12.5]
# Finished episode 96 with total reward -30.87334388094973, average reward -0.25727786567458105, distance to goal: 3.739190571840972, in 120 steps
# Started episode, with spawn: [10.804087475647663,5.376829586931496],  97, with goal: [12.5, 11.147953902675795]
# Finished episode 97 with total reward -258.7311964036647, average reward -2.1742117344845773, distance to goal: 11.367444350836783, in 119 steps
# Started episode, with spawn: [-1.7620829691311695,8.589627200795196],  98, with goal: [-0.48876383247263844, 7.674286024665335]
# Finished episode 98 with total reward -38.69727361112367, average reward -0.32247728009269727, distance to goal: 3.612837360379571, in 120 steps
# Started episode, with spawn: [-6.096519556387081,4.560019389403244],  99, with goal: [-9.390946427106828, 9.824130784919458]
# Finished episode 99 with total reward -16.707907757808304, average reward -0.13923256464840253, distance to goal: 3.2010374964501414, in 120 steps
# Started episode, with spawn: [11.372081259055648,-3.6585529922009785],  100, with goal: [9.49198777546134, 4.870470375458953]
# Finished episode 100 with total reward -245.11967331271705, average reward -2.475956296088051, distance to goal: 12.586412544063368, in 99 steps
# Started episode, with spawn: [-7.409575147121639,6.638523735535504],  101, with goal: [-0.42609474193776453, 8.909224999401362]
# Finished episode 101 with total reward -43.47371090288404, average reward -0.3622809241907003, distance to goal: 10.463123284569251, in 120 steps
# Started episode, with spawn: [-6.184620985536853,8.860416062939944],  102, with goal: [-6.78595430434217, 8.159821110393665]
# Finished episode 102 with total reward -49.44024954123989, average reward -0.41200207951033246, distance to goal: 4.241653413319162, in 120 steps
# Started episode, with spawn: [-2.5049871700073894,-2.5622893493745167],  103, with goal: [-0.1247278305643178, -7.24478665937246]
# Finished episode 103 with total reward -20.03915306174729, average reward -0.1669929421812274, distance to goal: 3.1253081500475206, in 120 steps
# Started episode, with spawn: [9.871527960763064,7.8817440364672],  104, with goal: [10.624862047001333, 2.7321578709712044]
# Finished episode 104 with total reward -31.18108583065285, average reward -0.25984238192210707, distance to goal: 4.947709779043802, in 120 steps
# Started episode, with spawn: [8.24031814121225,5.32696366045106],  105, with goal: [10.402205504869634, -0.7880440144596257]
# Finished episode 105 with total reward -15.377933735415906, average reward -0.12814944779513254, distance to goal: 3.429200818403942, in 120 steps
# Started episode, with spawn: [5.025703158464186,-1.5692195005425678],  106, with goal: [8.42473591806836, -7.216306347855005]
# Finished episode 106 with total reward -261.3846639558196, average reward -2.904274043953551, distance to goal: 14.067978580010914, in 90 steps
# Started episode, with spawn: [-1.155811876990052,3.859709436835125],  107, with goal: [6.603415647899492, 4.915161945934438]
# Finished episode 107 with total reward -197.60932237680865, average reward -4.819739570166065, distance to goal: 5.443299469296387, in 41 steps
# Started episode, with spawn: [8.882737986366038,0.47948440422849536],  108, with goal: [7.839158502656754, 2.2869218225660037]
# Finished episode 108 with total reward -71.51814593564265, average reward -0.5959845494636887, distance to goal: 9.852768691849482, in 120 steps
# Started episode, with spawn: [10.33795539959463,-3.5853972158257124],  109, with goal: [7.914910677678812, -4.675007406301993]
# Finished episode 109 with total reward -62.80621090938515, average reward -0.523385090911543, distance to goal: 8.639536050099613, in 120 steps
# Started episode, with spawn: [2.274084286603573,-0.028997247569725104],  110, with goal: [-0.9758959324228682, 5.316947838654156]
# Finished episode 110 with total reward -233.6207703260655, average reward -6.489465842390708, distance to goal: 10.921861873805812, in 36 steps
# Started episode, with spawn: [-1.8246004652562764,-2.2560703451709294],  111, with goal: [-4.676578862146143, -11.207496276548275]
# Finished episode 111 with total reward -221.45749090387991, average reward -2.6681625410106014, distance to goal: 8.827479212289903, in 83 steps
# Started episode, with spawn: [-4.929800728761212,5.2635822000898145],  112, with goal: [-7.282705847320585, -3.229829446898835]
# Finished episode 112 with total reward -38.95065969829104, average reward -0.324588830819092, distance to goal: 10.239263386929478, in 120 steps
# Started episode, with spawn: [2.2308585178923206,-4.3253822246642555],  113, with goal: [2.1750973784751237, -3.2652351330341367]
# Finished episode 113 with total reward -73.15117124240851, average reward -0.6095930936867375, distance to goal: 8.937344788144344, in 120 steps
# Started episode, with spawn: [-7.713420148689204,2.780238438887917],  114, with goal: [-10.950891816291298, 1.1586162882716837]
# Finished episode 114 with total reward -61.39798348828641, average reward -0.5116498624023867, distance to goal: 9.351251241907093, in 120 steps
# Started episode, with spawn: [-7.99234364422035,-9.417609940703452],  115, with goal: [-8.044457053006623, -10.257686441984323]
# Finished episode 115 with total reward -99.89598271584478, average reward -0.8324665226320398, distance to goal: 14.842480442484995, in 120 steps
# Started episode, with spawn: [7.569708064940066,9.801219739627157],  116, with goal: [5.060241840961757, 12.5]
# Finished episode 116 with total reward -274.0177457199941, average reward -2.915082401276533, distance to goal: 13.35577999079035, in 94 steps
# Started episode, with spawn: [-1.9852213623526804,4.731310422128988],  117, with goal: [0.187403247365733, 8.216902916092858]
# Finished episode 117 with total reward -89.50998945653721, average reward -0.7459165788044768, distance to goal: 15.850782053238628, in 120 steps
# Started episode, with spawn: [10.13114014362392,4.799066499997721],  118, with goal: [12.5, 6.866843638892465]
# Finished episode 118 with total reward -107.30116669118958, average reward -0.8941763890932465, distance to goal: 18.840924245974563, in 120 steps
# Started episode, with spawn: [5.902201246986785,-9.489025686205736],  119, with goal: [12.5, -9.169832347600282]
# Finished episode 119 with total reward -100.96112703654019, average reward -0.8413427253045016, distance to goal: 21.28443192324214, in 120 steps
# Started episode, with spawn: [-8.507966406076747,-9.049506330970692],  120, with goal: [-10.869064921575191, -3.3258413939731417]
# Finished episode 120 with total reward -37.83836173312908, average reward -0.31531968110940894, distance to goal: 7.215198399312131, in 120 steps
# Started episode, with spawn: [4.457007202998744,5.708984994097438],  121, with goal: [5.198330230364856, 7.559119761318356]
# Finished episode 121 with total reward -83.88550304792652, average reward -0.699045858732721, distance to goal: 12.665365276786279, in 120 steps
# Started episode, with spawn: [-0.9571423955274678,0.684862314148944],  122, with goal: [-1.153295955848669, -3.3382372334674555]
# Finished episode 122 with total reward -44.76610584487758, average reward -0.3730508820406465, distance to goal: 6.355499846219362, in 120 steps
# Started episode, with spawn: [-6.333781352574789,10.280994171016896],  123, with goal: [-11.975472235066558, 7.279143506141177]
# Finished episode 123 with total reward -76.40311104543476, average reward -0.6366925920452896, distance to goal: 14.63482724412762, in 120 steps
# Started episode, with spawn: [-0.7900202402331882,6.768044411834868],  124, with goal: [-3.9030759273894233, 6.571820582163669]
# Finished episode 124 with total reward -222.00580286473337, average reward -5.692456483711112, distance to goal: 5.31963882746365, in 39 steps
# Started episode, with spawn: [11.462081877214018,5.22218144933635],  125, with goal: [12.5, 5.163745277375879]
# Finished episode 125 with total reward -85.23657540505633, average reward -0.7103047950421361, distance to goal: 12.319004796545205, in 120 steps
# Started episode, with spawn: [-11.48653916551789,10.230188993493023],  126, with goal: [-12.5, 11.091981815124965]
# Finished episode 126 with total reward -98.1106796371826, average reward -0.8175889969765217, distance to goal: 13.740284139652559, in 120 steps
# Started episode, with spawn: [11.172808785820415,-4.094918968361682],  127, with goal: [6.423690011444181, -10.796357089137432]
# Finished episode 127 with total reward 0.8497173512033207, average reward 0.007080977926694339, distance to goal: 1.4374297400273017, in 120 steps
# Started episode, with spawn: [8.540897407547366,7.4410851272669625],  128, with goal: [5.224075925094139, 2.4541830944847183]
# Finished episode 128 with total reward -29.310508875719204, average reward -0.24425424063099338, distance to goal: 4.996604609195449, in 120 steps
# Started episode, with spawn: [9.310609244594815,1.827412968724179],  129, with goal: [7.1848333141230825, 0.3362657213310738]
# Finished episode 129 with total reward 93.363978047016, average reward 1.3934922096569553, distance to goal: 0.12890827402801017, in 67 steps
# Started episode, with spawn: [-9.84736966439448,0.5867015101063693],  130, with goal: [-11.409640024502819, -0.519388651233099]
# Finished episode 130 with total reward -70.18941463570553, average reward -0.5849117886308794, distance to goal: 9.69776454385276, in 120 steps
# Started episode, with spawn: [-9.995015779336638,5.599427481502023],  131, with goal: [-12.5, 11.810244310100941]
# Finished episode 131 with total reward -34.83039845402187, average reward -0.2902533204501822, distance to goal: 7.252827671237943, in 120 steps
# Started episode, with spawn: [10.630511233390308,-10.929335826047254],  132, with goal: [12.5, -12.5]
# Finished episode 132 with total reward -54.02069447679477, average reward -0.45017245397328975, distance to goal: 7.65257358632964, in 120 steps
# Started episode, with spawn: [-6.3849681524629505,-10.530043934739224],  133, with goal: [-6.681066763059539, -11.022296147948534]
# Finished episode 133 with total reward -223.1952748148201, average reward -7.199847574671616, distance to goal: 3.517358357872413, in 31 steps
# Started episode, with spawn: [6.194551665556649,5.1417880753929985],  134, with goal: [6.671603835164502, 3.8841320540326416]
# Finished episode 134 with total reward -37.62078095971734, average reward -0.31350650799764446, distance to goal: 2.800731562579501, in 120 steps
# Started episode, with spawn: [1.3864184739966827,9.262773839334447],  135, with goal: [-5.832766697559003, 12.270687716924336]
# Finished episode 135 with total reward -43.89648565913599, average reward -0.36580404715946657, distance to goal: 9.59334653713861, in 120 steps
# Started episode, with spawn: [-2.9317456789691523,-9.072704792981607],  136, with goal: [0.137503079499667, -12.5]
# Finished episode 136 with total reward -38.66611011589526, average reward -0.32221758429912717, distance to goal: 6.765015715550697, in 120 steps
# Started episode, with spawn: [-3.8943672845930895,7.803712548230962],  137, with goal: [-5.773830218603525, 4.212046660774423]
# Finished episode 137 with total reward -29.995891908493192, average reward -0.24996576590410993, distance to goal: 3.683265231635243, in 120 steps
# Started episode, with spawn: [2.699602144364505,3.5331141262215837],  138, with goal: [3.520360936206968, 3.8046994893198502]
# Finished episode 138 with total reward -57.427855687506, average reward -0.47856546406255, distance to goal: 5.717930909678552, in 120 steps
# Started episode, with spawn: [-11.437674366825531,-0.1628196158503048],  139, with goal: [-12.5, -1.1344895856681472]
# Finished episode 139 with total reward -60.295475962652105, average reward -0.5024622996887675, distance to goal: 6.873649120992941, in 120 steps
# Started episode, with spawn: [-5.4808254193003645,-9.126386027557361],  140, with goal: [-6.749710204485668, -10.679250944200998]
# Finished episode 140 with total reward -234.64493391142, average reward -2.076503839924071, distance to goal: 3.172628486973473, in 113 steps
# Started episode, with spawn: [-9.208700294697017,-3.8905387205180855],  141, with goal: [-12.5, -0.721765982925139]
# Finished episode 141 with total reward -46.36159030139758, average reward -0.38634658584497983, distance to goal: 6.897173149768458, in 120 steps
# Started episode, with spawn: [-4.385717226805621,8.766987365386822],  142, with goal: [-12.5, 8.788734303507796]
# Finished episode 142 with total reward -49.1860767747989, average reward -0.40988397312332414, distance to goal: 10.54723444315486, in 120 steps
# Started episode, with spawn: [-5.470895107668184,8.88060211453989],  143, with goal: [-12.116837528616387, 9.618679592433432]
# Finished episode 143 with total reward -46.90259199462479, average reward -0.39085493328853993, distance to goal: 8.927208367846195, in 120 steps
# Started episode, with spawn: [-9.134576413096676,-5.6180661859416805],  144, with goal: [-9.139186463303016, -4.43576474004878]
# Finished episode 144 with total reward 100.18609015115486, average reward 5.272952113218676, distance to goal: 0.0853284137573534, in 19 steps
# Started episode, with spawn: [0.5378486359093966,7.57695701018816],  145, with goal: [-0.49592031525674307, 6.325488490100787]
# Finished episode 145 with total reward -33.631868089294, average reward -0.28026556741078335, distance to goal: 1.6896592601576332, in 120 steps
# Started episode, with spawn: [-2.7588883213058146,-4.591805746844988],  146, with goal: [-4.214922160208937, 3.2455429215407134]
# Finished episode 146 with total reward -43.488892163535, average reward -0.36240743469612496, distance to goal: 10.6186868229135, in 120 steps
# Started episode, with spawn: [-8.722181489353678,-10.314389417861792],  147, with goal: [-5.047596054767506, -4.955778544409527]
# Finished episode 147 with total reward -5.45019101235949, average reward -0.04541825843632908, distance to goal: 2.094762641955292, in 120 steps
# Started episode, with spawn: [-10.066578055360566,4.722148379297572],  148, with goal: [-12.5, 2.046153127089848]
# Finished episode 148 with total reward -53.32083733846432, average reward -0.44434031115386935, distance to goal: 7.697459109183766, in 120 steps
# Started episode, with spawn: [-2.263222776878907,-8.931359017671229],  149, with goal: [2.073593321567703, -0.1348015003386287]
# Finished episode 149 with total reward -18.573373995797297, average reward -0.15477811663164415, distance to goal: 7.90373371273901, in 120 steps
# Started episode, with spawn: [2.2855802869598545,3.277998164756026],  150, with goal: [4.04262098780567, 2.022566884481646]
# Finished episode 150 with total reward -199.71411642625907, average reward -199.71411642625907, distance to goal: 2.0661042604203055, in 1 steps
# Started episode, with spawn: [9.541099262673427,-1.6946423279814127],  151, with goal: [6.46609458007229, -5.039923699820754]
# Finished episode 151 with total reward -239.94975475590397, average reward -1.9995812896325331, distance to goal: 6.216468053562913, in 120 steps
# Started episode, with spawn: [2.0282107852350695,4.311475571133371],  152, with goal: [1.565195345907338, 9.798912141976341]
# Finished episode 152 with total reward -53.03916511765332, average reward -0.441993042647111, distance to goal: 10.351248574503698, in 120 steps
# Started episode, with spawn: [7.7427927632395885,3.5045256061523116],  153, with goal: [5.3605912541238006, 4.530881125960315]
# Finished episode 153 with total reward -233.08486692710036, average reward -2.7102891503151203, distance to goal: 4.533706067955563, in 86 steps
# Started episode, with spawn: [-4.366370833045072,-5.581389339031719],  154, with goal: [3.4214570891413, -5.926702831779566]
# Finished episode 154 with total reward -218.35596612093238, average reward -2.662877635621127, distance to goal: 7.638534291908903, in 82 steps
# Started episode, with spawn: [-7.5883387154876925,6.347172997371231],  155, with goal: [-0.7636707767784037, 12.5]
# Finished episode 155 with total reward -20.70627895888645, average reward -0.1725523246573871, distance to goal: 7.679032239107756, in 120 steps
# Started episode, with spawn: [3.2902455843558904,-8.245279160015118],  156, with goal: [3.999466976894986, -1.8633125250431775]
# Finished episode 156 with total reward -23.532330297608347, average reward -0.19610275248006956, distance to goal: 4.653735104201501, in 120 steps
# Started episode, with spawn: [-9.253656147613,-6.0366055963587195],  157, with goal: [-12.325122058946725, -9.303096097453881]
# Finished episode 157 with total reward -60.80289777446958, average reward -0.5066908147872465, distance to goal: 10.325871015430655, in 120 steps
# Started episode, with spawn: [-5.172052109909888,3.313656210883968],  158, with goal: [-3.3394685403102393, 0.5293528125010822]
# Finished episode 158 with total reward -30.235336562412268, average reward -0.2519611380201022, distance to goal: 3.6200578980083593, in 120 steps
# Started episode, with spawn: [2.934483704174605,-2.5210939632578864],  159, with goal: [0.294523935732637, -6.3492001155744155]
# Finished episode 159 with total reward -200.47763243317223, average reward -200.47763243317223, distance to goal: 4.662343943851115, in 1 steps
# Started episode, with spawn: [-0.8036429035891199,8.01657908167508],  160, with goal: [-4.7213949184539, 0.3448145278351964]
# Finished episode 160 with total reward -18.856199687020965, average reward -0.15713499739184136, distance to goal: 6.0687817139353, in 120 steps
# Started episode, with spawn: [4.644801109176864,11.316379906165999],  161, with goal: [3.9755088205224527, 11.505547380055221]
# Finished episode 161 with total reward -45.68866022373101, average reward -0.3807388351977584, distance to goal: 3.911013871232828, in 120 steps
# Started episode, with spawn: [3.3713218445197892,-10.156590487895912],  162, with goal: [3.216812928479099, -9.704653767671706]
# Finished episode 162 with total reward -54.413830419016435, average reward -0.45344858682513695, distance to goal: 4.763609937888649, in 120 steps
# Started episode, with spawn: [-8.826329876219729,-8.624930175416996],  163, with goal: [-3.293407835085647, -2.8494659873800465]
# Finished episode 163 with total reward -199.18191693124066, average reward -5.858291674448255, distance to goal: 6.204620303593223, in 34 steps
# Started episode, with spawn: [-9.595297609121573,-11.009016396782975],  164, with goal: [-8.546549682343997, -12.5]
# Finished episode 164 with total reward -53.503655248147396, average reward -0.44586379373456164, distance to goal: 6.350268670138066, in 120 steps
# Started episode, with spawn: [0.8420922681391438,9.211219440209614],  165, with goal: [2.6442580036371366, 9.447925447277095]
# Finished episode 165 with total reward -40.70333657999713, average reward -0.33919447149997606, distance to goal: 4.30529845366426, in 120 steps
# Started episode, with spawn: [10.993910277925984,9.403191975762994],  166, with goal: [12.5, 9.377069409945369]
# Finished episode 166 with total reward -49.990091844993785, average reward -0.41658409870828156, distance to goal: 6.010184067815377, in 120 steps
# Started episode, with spawn: [-9.998476346382251,7.730954655295957],  167, with goal: [-12.5, 12.5]
# Finished episode 167 with total reward -37.40758948000569, average reward -0.31172991233338077, distance to goal: 6.352755184659371, in 120 steps
# Started episode, with spawn: [-5.835080731347995,-5.186988067109388],  168, with goal: [-3.6903324522452765, -8.440102484382031]
# Finished episode 168 with total reward -29.877504546086538, average reward -0.24897920455072114, distance to goal: 3.833996903794517, in 120 steps
# Started episode, with spawn: [6.398924048457314,7.375514059570026],  169, with goal: [5.594374167967692, 2.6306805919009735]
# Finished episode 169 with total reward -32.44226020973959, average reward -0.27035216841449655, distance to goal: 4.850083426002119, in 120 steps
# Started episode, with spawn: [-1.2753945361789683,-10.824119883173625],  170, with goal: [2.1736328199922283, -12.5]
# Finished episode 170 with total reward -46.235643911477965, average reward -0.3852970325956497, distance to goal: 7.258061977833663, in 120 steps
# Started episode, with spawn: [10.9876868631674,-5.008308670355062],  171, with goal: [12.5, -8.750306142540948]
# Finished episode 171 with total reward -37.30255529749475, average reward -0.3108546274791229, distance to goal: 5.670453674920282, in 120 steps
# Started episode, with spawn: [10.442638994368409,8.282293207999206],  172, with goal: [12.5, 12.5]
# Finished episode 172 with total reward -47.24478101875646, average reward -0.3937065084896372, distance to goal: 8.523642826461408, in 120 steps
# Started episode, with spawn: [-4.285836065065494,-6.015566176338765],  173, with goal: [-0.5216512559573978, -4.90476734165125]
# Finished episode 173 with total reward -32.20354441800545, average reward -0.2683628701500454, distance to goal: 4.676096273822851, in 120 steps
# Started episode, with spawn: [-4.252236184417341,7.765824727932852],  174, with goal: [-4.155708377775315, 7.555587567351448]
# Finished episode 174 with total reward 94.17907324744259, average reward 3.363538330265807, distance to goal: 0.05266317415450883, in 28 steps
# Started episode, with spawn: [4.3291915002045105,7.020595910816521],  175, with goal: [-0.6290437023560598, 6.831663739777871]
# Finished episode 175 with total reward -48.02034737710079, average reward -0.40016956147583993, distance to goal: 7.38104778938634, in 120 steps
# Started episode, with spawn: [-2.4444020232849493,-8.459985981538361],  176, with goal: [-2.723444813538059, -3.064664093942027]
# Finished episode 176 with total reward -22.20153523863133, average reward -0.18501279365526108, distance to goal: 3.875872977633282, in 120 steps
# Started episode, with spawn: [-8.912786776949822,3.698657970204639],  177, with goal: [-9.451313126313428, 5.193309817386517]
# Finished episode 177 with total reward -40.438861079181365, average reward -0.33699050899317806, distance to goal: 2.582240975674566, in 120 steps
# Started episode, with spawn: [5.729839483149561,-3.87089798917083],  178, with goal: [-0.3818400926286811, -3.289418533334686]
# ...
# Finished episode 1587 with total reward -48.31985213701681, average reward -0.4026654344751401, distance to goal: 7.025292134322909, in 120 steps
# Started episode, with spawn: [-6.104653055273651,7.946469096445451],  1588, with goal: [-6.219492649833559, 10.079869537811724]
# Finished episode 1588 with total reward -34.34041216412607, average reward -0.28617010136771726, distance to goal: 2.7173123799095933, in 120 steps
# Started episode, with spawn: [-10.224313716259646,7.187081446724772],  1589, with goal: [-9.521607756593479, 7.439873397892568]
# Finished episode 1589 with total reward -37.57318989490381, average reward -0.3131099157908651, distance to goal: 1.3367114124411348, in 120 steps
# Started episode, with spawn: [7.539528335368896,-4.329097497714983],  1590, with goal: [12.289068579594508, -6.921238423220589]
# Finished episode 1590 with total reward -226.7183934788111, average reward -1.9887578375334307, distance to goal: 5.28935215794951, in 114 steps
# Started episode, with spawn: [-11.181437455818118,8.676817592228296],  1591, with goal: [-12.393169832302501, 12.5]
# Finished episode 1591 with total reward -210.02969586431902, average reward -8.401187834572761, distance to goal: 5.548311924494189, in 25 steps
# Started episode, with spawn: [-8.600566680298082,5.883508708819225],  1592, with goal: [-12.5, 12.5]
# Finished episode 1592 with total reward -33.10691221025752, average reward -0.27589093508547935, distance to goal: 7.773092168392278, in 120 steps
# Started episode, with spawn: [-1.5192514482719428,-7.666171549559483],  1593, with goal: [5.315157317359107, -12.5]
# Finished episode 1593 with total reward -31.15720818865589, average reward -0.2596434015721324, distance to goal: 8.86981644574992, in 120 steps
# Started episode, with spawn: [4.48747012446351,-8.075040499049488],  1594, with goal: [-1.5384138253196173, -12.5]
# Finished episode 1594 with total reward -31.29236684691571, average reward -0.2607697237242976, distance to goal: 8.336612715226694, in 120 steps
# Started episode, with spawn: [-6.093687676779081,8.84531766316707],  1595, with goal: [-6.0280110014994115, 6.635124062960897]
# Finished episode 1595 with total reward -27.395299472488908, average reward -0.2282941622707409, distance to goal: 1.7882142624806874, in 120 steps
# Started episode, with spawn: [8.286339251280015,2.9361408350784295],  1596, with goal: [3.70079550772589, 8.380735327312195]
# Finished episode 1596 with total reward -28.576711713310107, average reward -0.23813926427758422, distance to goal: 6.029222310097907, in 120 steps
# Started episode, with spawn: [7.926250822900197,-8.057072296684439],  1597, with goal: [12.5, -4.426083516591433]
# Finished episode 1597 with total reward -202.05995070734392, average reward -67.35331690244797, distance to goal: 6.134489650687181, in 3 steps
# Started episode, with spawn: [0.33093148859781074,2.7580351720278973],  1598, with goal: [-3.7533279441659317, 5.429649900945325]
# Finished episode 1598 with total reward -201.32777579153802, average reward -28.761110827362575, distance to goal: 4.776128938757059, in 7 steps
# Started episode, with spawn: [-6.0186338117063025,-5.5399156718660905],  1599, with goal: [-10.184772470866562, -7.241931674598119]
# Finished episode 1599 with total reward -34.10346003378023, average reward -0.2841955002815019, distance to goal: 4.248096935071118, in 120 steps
# Started episode, with spawn: [4.966074511798283,-6.480638719611765],  1600, with goal: [4.070999099170935, -1.6056626820798323]
# Finished episode 1600 with total reward -34.29458762469211, average reward -0.2857882302057676, distance to goal: 5.493329902433103, in 120 steps
# Started episode, with spawn: [6.864323564006401,11.082855514135723],  1601, with goal: [0.8586743289215937, 6.464408600225026]
# Finished episode 1601 with total reward -215.05906618221726, average reward -5.001373632144587, distance to goal: 8.836324251229295, in 43 steps
# Started episode, with spawn: [7.151126554288556,0.5169323131507895],  1602, with goal: [4.230898820611859, 6.14909238422293]
# Finished episode 1602 with total reward -28.994694256791988, average reward -0.24162245213993322, distance to goal: 5.710921170578395, in 120 steps
# Started episode, with spawn: [-6.909122960039589,3.1513754540290044],  1603, with goal: [-5.786913400404676, -1.586188212274715]
# Finished episode 1603 with total reward -31.712327577133117, average reward -0.2642693964761093, distance to goal: 5.21615507407594, in 120 steps
# Started episode, with spawn: [-3.8279755384136847,-11.175537542205664],  1604, with goal: [-2.487939717619387, -12.5]
# Finished episode 1604 with total reward -44.46209825695409, average reward -0.37051748547461744, distance to goal: 5.006836457702696, in 120 steps
# Started episode, with spawn: [3.7290115520064067,-8.662671871410792],  1605, with goal: [2.20841625672664, -12.5]
# Finished episode 1605 with total reward -214.07590398547094, average reward -4.116844307412903, distance to goal: 4.207149305919427, in 52 steps
# Started episode, with spawn: [-2.6557234880910627,8.605943525701697],  1606, with goal: [-2.910848699867873, 7.665318905361221]
# Finished episode 1606 with total reward -28.830951225479335, average reward -0.24025792687899447, distance to goal: 1.1863769152507162, in 120 steps
# Started episode, with spawn: [-4.2535764472606985,-1.9772940296937271],  1607, with goal: [-0.4065766673567879, 6.046490713334821]
# Finished episode 1607 with total reward -29.806650846402146, average reward -0.24838875705335123, distance to goal: 8.894130311308421, in 120 steps
# Started episode, with spawn: [8.993095186748512,-1.9179671164738998],  1608, with goal: [7.480926390555243, -3.780383440273259]
# Finished episode 1608 with total reward -208.86931171968737, average reward -12.28643010115808, distance to goal: 3.5790350775265263, in 17 steps
# Started episode, with spawn: [-5.821821497603578,-4.775079143823881],  1609, with goal: [-2.0377011740431974, 2.3671285216268014]
# Finished episode 1609 with total reward -33.24341292783539, average reward -0.2770284410652949, distance to goal: 8.784862044001143, in 120 steps
# Started episode, with spawn: [-10.695577381383144,10.498332383174542],  1610, with goal: [-12.5, 10.617382794275283]
# Finished episode 1610 with total reward -46.04643732470271, average reward -0.38372031103918924, distance to goal: 6.2260695598975175, in 120 steps
# Started episode, with spawn: [6.978510744474381,-9.373773518293852],  1611, with goal: [4.418132930759979, -10.931782318904999]
# Finished episode 1611 with total reward -196.83745154622972, average reward -4.920936288655743, distance to goal: 0.28192768405379387, in 40 steps
# Started episode, with spawn: [-6.915163222165945,10.189702631500445],  1612, with goal: [-7.77919682110462, 11.477331146972908]
# Finished episode 1612 with total reward -237.14783482842677, average reward -2.009727413800227, distance to goal: 3.681213765997411, in 118 steps
# Started episode, with spawn: [-0.5948831930623761,1.5769046310832966],  1613, with goal: [-5.337931303720897, 7.745235868891727]
# Finished episode 1613 with total reward -23.95441490967051, average reward -0.19962012424725425, distance to goal: 6.189879290040782, in 120 steps
# Started episode, with spawn: [8.814270044834423,-9.529983087235559],  1614, with goal: [9.611374891271275, -7.750963617955245]
# Finished episode 1614 with total reward -27.61553402822274, average reward -0.2301294502351895, distance to goal: 2.05339586125414, in 120 steps
# Started episode, with spawn: [9.862210427921287,11.014976911349486],  1615, with goal: [12.5, 7.365009913078875]
# Finished episode 1615 with total reward -214.0109635495725, average reward -5.944748987488125, distance to goal: 6.6216261388309166, in 36 steps
# Started episode, with spawn: [-1.115917991201302,-8.69498776569618],  1616, with goal: [0.45406406828283963, -12.5]
# Finished episode 1616 with total reward -214.9396312100787, average reward -4.214502572746641, distance to goal: 4.676344001408968, in 51 steps
# Started episode, with spawn: [-2.6956221107154654,-10.312585401492258],  1617, with goal: [-3.9531979166963933, -2.4992379225384376]
# Finished episode 1617 with total reward -18.43510142433126, average reward -0.1536258452027605, distance to goal: 5.397305163639202, in 120 steps
# Started episode, with spawn: [10.372494797893694,-2.9375821590177793],  1618, with goal: [10.944362032094741, 6.337724603327214]
# Finished episode 1618 with total reward -10.849828102308193, average reward -0.09041523418590161, distance to goal: 6.927425639765192, in 120 steps
# Started episode, with spawn: [-4.0283732489350115,-11.494953139429413],  1619, with goal: [-1.5200970758070982, -12.5]
# Finished episode 1619 with total reward -41.075029747369, average reward -0.34229191456140834, distance to goal: 5.611750851633527, in 120 steps
# Started episode, with spawn: [9.969605685993802,1.546383432017457],  1620, with goal: [12.5, 4.885206547003069]
# Finished episode 1620 with total reward -33.069236165308304, average reward -0.27557696804423587, distance to goal: 5.182886865907894, in 120 steps
# Started episode, with spawn: [9.000129854593627,-4.747229270533401],  1621, with goal: [3.3789391833342357, 3.2870286904367525]
# Finished episode 1621 with total reward -27.731774759009156, average reward -0.23109812299174295, distance to goal: 8.871255933167586, in 120 steps
# Started episode, with spawn: [3.166030558465641,0.9143627820406959],  1622, with goal: [1.8853885130696706, -2.00722915847321]
# Finished episode 1622 with total reward -227.66023539675828, average reward -3.397913961145646, distance to goal: 4.990598913502792, in 67 steps
# Started episode, with spawn: [10.033665676064857,-5.890598768014799],  1623, with goal: [4.345631728780289, 1.3311921558981155]
# Finished episode 1623 with total reward -21.222960642102244, average reward -0.17685800535085203, distance to goal: 7.354840078292122, in 120 steps
# Started episode, with spawn: [-9.436576324658155,-10.769632627876431],  1624, with goal: [-9.515831212426235, -10.78257266997492]
# Finished episode 1624 with total reward -225.26981296526262, average reward -6.436280370436075, distance to goal: 4.018789612045425, in 35 steps
# Started episode, with spawn: [4.0149698915491,6.269572128271751],  1625, with goal: [3.682111540571596, 7.093838341550136]
# Finished episode 1625 with total reward -208.9402276158009, average reward -17.411685634650073, distance to goal: 2.4797707375497793, in 12 steps
# Started episode, with spawn: [-0.14197576812239276,9.315883240663354],  1626, with goal: [-0.988431722188628, 12.470434709677612]
# Finished episode 1626 with total reward -206.66587775992767, average reward -17.222156479993973, distance to goal: 4.225562781120866, in 12 steps
# Started episode, with spawn: [9.813423607538024,10.856763088546618],  1627, with goal: [7.915482167792506, 10.183294884950461]
# Finished episode 1627 with total reward -22.131131217368967, average reward -0.18442609347807473, distance to goal: 3.5265217107401168, in 120 steps
# Started episode, with spawn: [-6.372065151731644,8.142329566303427],  1628, with goal: [-7.895001896842314, 2.05902844879665]
# Finished episode 1628 with total reward -26.094702662569624, average reward -0.21745585552141353, distance to goal: 5.3338923196972585, in 120 steps
# Started episode, with spawn: [2.1048758322002428,-6.107251127570686],  1629, with goal: [10.340166407645214, -0.4703318230075535]
# Finished episode 1629 with total reward -40.84532091292607, average reward -0.3403776742743839, distance to goal: 13.272074004337197, in 120 steps
# Started episode, with spawn: [-9.11801389148173,3.168571842950225],  1630, with goal: [-8.360993690293778, 2.752197066730397]
# Finished episode 1630 with total reward 102.2182949915691, average reward 17.03638249859485, distance to goal: 0.19114557953782488, in 6 steps
# Started episode, with spawn: [5.9488047242910795,-7.1051660961854175],  1631, with goal: [-0.3820336357370602, -6.782144758772885]
# Finished episode 1631 with total reward -41.988633073901354, average reward -0.3499052756158446, distance to goal: 7.430085637802848, in 120 steps
# Started episode, with spawn: [11.242677154031938,7.541354905568191],  1632, with goal: [12.5, 0.6954385807139474]
# Finished episode 1632 with total reward -27.46873184287822, average reward -0.22890609869065184, distance to goal: 8.014473426281034, in 120 steps
# Started episode, with spawn: [-5.0889745751264375,-2.599132433661673],  1633, with goal: [1.1314386250383226, -4.146533298544863]
# Finished episode 1633 with total reward -213.56721108890702, average reward -3.682193294636328, distance to goal: 6.376924717022522, in 58 steps
# Started episode, with spawn: [-8.060942607365575,-9.188927870546102],  1634, with goal: [-10.212414230702182, -12.5]
# Finished episode 1634 with total reward -234.9259811968572, average reward -2.397203889763849, distance to goal: 5.910693069495051, in 98 steps
# Started episode, with spawn: [3.840560722047087,-2.2464220704027564],  1635, with goal: [3.43928394533056, -2.045615312345479]
# Finished episode 1635 with total reward -48.25505442460476, average reward -0.402125453538373, distance to goal: 3.403213902060305, in 120 steps
# Started episode, with spawn: [7.470410258794669,5.04775599913971],  1636, with goal: [8.8872538077918, 4.203504303966298]
# Finished episode 1636 with total reward -35.06768538577065, average reward -0.2922307115480888, distance to goal: 3.3230036782823515, in 120 steps
# Started episode, with spawn: [-7.159000693145093,-5.856236561622513],  1637, with goal: [-1.7835712685904577, -7.597116756230299]
# Finished episode 1637 with total reward -32.59383729191788, average reward -0.27161531076598233, distance to goal: 6.489184287819407, in 120 steps
# Started episode, with spawn: [9.236569583153074,4.346874515214143],  1638, with goal: [12.5, 1.3493324354108625]
# Finished episode 1638 with total reward -32.95370346721643, average reward -0.2746141955601369, distance to goal: 5.65102469780705, in 120 steps
# Started episode, with spawn: [-2.666510293501929,5.421660692404515],  1639, with goal: [-4.3976863206266925, 9.300500551672979]
# Finished episode 1639 with total reward -30.46669812616225, average reward -0.25388915105135207, distance to goal: 3.921492864386109, in 120 steps
# Started episode, with spawn: [0.3382110592597751,-0.19357416372861636],  1640, with goal: [8.944773842283514, -4.214592377104467]
# Finished episode 1640 with total reward -40.89193927540991, average reward -0.3407661606284159, distance to goal: 12.248273862834436, in 120 steps
# Started episode, with spawn: [-4.128762465883568,9.780952308323773],  1641, with goal: [3.5721265314136668, 11.128174199103578]
# Finished episode 1641 with total reward -32.1294696720287, average reward -0.2677455806002392, distance to goal: 9.102331819040774, in 120 steps
# Started episode, with spawn: [-10.98814971295016,-6.031350682404318],  1642, with goal: [-10.333089993425585, -6.31486926194258]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 29
#      26 slam_node.update_map(robotId)
#      28 # choose and perform action
# ---> 29 s_ = dict_to_tensors(state)
#      30 action, _ = agent.actor.sample(s_['map'], s_['lidar'], s_['robot'])
#      31 action = action.squeeze().detach().cpu().numpy()
#
# File c:\Users\joaqu\Documents\CodeScripts\DL\AutoNav\scripts\utils.py:27, in dict_to_tensors(dict, dtype)
#      26 def dict_to_tensors(dict, dtype=torch.float32):
# ---> 27     tensor_dict = {key: torch.tensor(value, dtype=dtype).unsqueeze(0).to(device) for key, value in dict.items()}
#      28     return tensor_dict
#
# File c:\Users\joaqu\Documents\CodeScripts\DL\AutoNav\scripts\utils.py:27, in <dictcomp>(.0)
#      26 def dict_to_tensors(dict, dtype=torch.float32):
# ---> 27     tensor_dict = {key: torch.tensor(value, dtype=dtype).unsqueeze(0).to(device) for key, value in dict.items()}
#      28     return tensor_dict
#
# KeyboardInterrupt:

# %%
# Save training data
with open('training_log/training_log_2.json', 'w') as file:
    json.dump({'Reward': reward_tracking, 'Distance': dist_goal_tracking, 'Steps': step_tracking}, file)
